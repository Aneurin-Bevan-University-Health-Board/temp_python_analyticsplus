# %% [markdown]
# # Analytics+ Example Notebook
# High-power environment ready.

# %%
import polars as pl
from google.cloud import bigquery

client = bigquery.Client(project="your-gcp-project")
df_pd = client.query("SELECT 'hello from BigQuery' AS message").to_dataframe()
df_pl = pl.from_pandas(df_pd)
print(df_pl)
